# %% [markdown]
# <a href="https://colab.research.google.com/github/nafis-saad/Assignments/blob/main/Copy_of_Main_Bikeshare_do_not_touch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_json("/content/drive/MyDrive/Tweetpy/Twitter_EVs_2020-01.json", encoding ='utf-8')

# %%
#import json
#import csv
#from google.colab import files
##uploaded = files.upload()

# %%
#uploaded["Twitter_EVs_2020-01.json"].decode("utf-8").split("\r\n")

# %% [markdown]
# # User **Location**

# %%
with pd.option_context('display.max_colwidth', None):
  print(df["user"][6])
# Out:
# {'created_at': '2013-10-14T06:14:07.000Z', 'description': 'Democrat in OK. Supporter of universal healthcare, combating climate change, comprehensive immigration reform, & all things that make us a better country.', 'id': '1960044362', 'name': 'Sarah', 'profile_image_url': 'https://pbs.twimg.com/profile_images/611075059860398080/UYL_KAm4_normal.jpg', 'public_metrics': {'followers_count': 122, 'following_count': 1280, 'listed_count': 1, 'tweet_count': 67203}, 'username': 'sbclifton77', 'verified': False}

# %%
df
# Out:
#         author_id      conversation_id                created_at  \
# 0        22788836  1223395490366025728 2020-01-31 23:59:49+00:00
# 1      3157671046  1223383749263593472 2020-01-31 23:59:11+00:00
# 2       181634813  1223394798876479488 2020-01-31 23:57:04+00:00
# 3      1633428576  1223394344545275904 2020-01-31 23:55:15+00:00
# 4      1225992186  1223358325452087296 2020-01-31 23:55:10+00:00
# ...           ...                  ...                       ...
# 27263  2612253354  1212163653568540672 2020-01-01 00:08:30+00:00
# 27264  2221442917  1212163086624247808 2020-01-01 00:06:15+00:00
# 27265   114743976  1212161757105577984 2020-01-01 00:00:58+00:00
# 27266  3279247754  1212161708803801088 2020-01-01 00:00:46+00:00
# 27267  2491046567  1212161581670391808 2020-01-01 00:00:16+00:00
#
#       edit_history_tweet_ids  \
# 0      [1223395490366025728]
# 1      [1223395330974191617]
# 2      [1223394798876479489]
# 3      [1223394344545275905]
# 4      [1223394321560244224]
# ...

# %%
n = df.shape[0]
print(n)
df["user_location"]= "NaN"
for i in range(n):
  if 'location' in df['user'][i]:
    #df["nafis"][i]= df["user"][i]['location']
    df["user_location"][i]=  df["user"][i]['location']

    #print(df1)
# Out:
# 27268
# <ipython-input-8-24c22de337d8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["user_location"][i]=  df["user"][i]['location']

# %%
print(df.head())
# Out:
#     author_id      conversation_id                created_at  \
# 0    22788836  1223395490366025728 2020-01-31 23:59:49+00:00
# 1  3157671046  1223383749263593472 2020-01-31 23:59:11+00:00
# 2   181634813  1223394798876479488 2020-01-31 23:57:04+00:00
# 3  1633428576  1223394344545275904 2020-01-31 23:55:15+00:00
# 4  1225992186  1223358325452087296 2020-01-31 23:55:10+00:00
#
#   edit_history_tweet_ids                                           entities  \
# 0  [1223395490366025728]  {'annotations': [{'end': 7, 'normalized_text':...
# 1  [1223395330974191617]  {'mentions': [{'end': 12, 'id': '23829152', 's...
# 2  [1223394798876479489]  {'annotations': [{'end': 71, 'normalized_text'...
# 3  [1223394344545275905]  {'annotations': [{'end': 40, 'normalized_text'...
# 4  [1223394321560244224]  {'mentions': [{'end': 15, 'id': '58885604', 's...
#
#                     id lang  \
# 0  1223395490366025728   en
# 1  1223395330974191616   en
# 2  1223394798876479488   en
# ...

# %%
df['user_location'].value_counts()
# Out:
# NaN                  5792
# Washington, DC        261
# Los Angeles, CA       235
# London, England       221
# Center Valley, PA     218
#                      ...
# srilanka                1
# Southaven, MS           1
# The TARDIS              1
# sarasota fl             1
# Patchogue, NY           1
# Name: user_location, Length: 8156, dtype: int64

# %% [markdown]
# ## ***Tweet_location***

# %%
import re
i=0
df['twitter_places_nafis']="NaN"
for value in df['twitter_places']:
    if isinstance(value, dict):
      my_string = str(value)
      matches = re.findall(r'\[(.*?)\]', my_string)
      df['twitter_places_nafis'][i] = matches
      i += 1
    else:
      df['twitter_places_nafis'][i] = "NaN"
      i += 1
# Out:
# <ipython-input-11-3ee425d8dc57>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['twitter_places_nafis'][i] = "NaN"
# <ipython-input-11-3ee425d8dc57>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['twitter_places_nafis'][i] = matches

# %%
df['twitter_places_nafis']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2        [-96.85743, 32.9971507, -96.612371, 33.1253341]
# 3                                                    NaN
# 4                                                    NaN
#                               ...
# 27263                                                NaN
# 27264       [80.056161, 12.850328, 80.268192, 13.028593]
# 27265                                                NaN
# 27266                                                NaN
# 27267                                                NaN
# Name: twitter_places_nafis, Length: 27268, dtype: object

# %%
df
# Out:
#         author_id      conversation_id                created_at  \
# 0        22788836  1223395490366025728 2020-01-31 23:59:49+00:00
# 1      3157671046  1223383749263593472 2020-01-31 23:59:11+00:00
# 2       181634813  1223394798876479488 2020-01-31 23:57:04+00:00
# 3      1633428576  1223394344545275904 2020-01-31 23:55:15+00:00
# 4      1225992186  1223358325452087296 2020-01-31 23:55:10+00:00
# ...           ...                  ...                       ...
# 27263  2612253354  1212163653568540672 2020-01-01 00:08:30+00:00
# 27264  2221442917  1212163086624247808 2020-01-01 00:06:15+00:00
# 27265   114743976  1212161757105577984 2020-01-01 00:00:58+00:00
# 27266  3279247754  1212161708803801088 2020-01-01 00:00:46+00:00
# 27267  2491046567  1212161581670391808 2020-01-01 00:00:16+00:00
#
#       edit_history_tweet_ids  \
# 0      [1223395490366025728]
# 1      [1223395330974191617]
# 2      [1223394798876479489]
# 3      [1223394344545275905]
# 4      [1223394321560244224]
# ...

# %% [markdown]
# # **GEO-LOcation **

# %%
with pd.option_context('display.max_colwidth', None):
  print(df["geo"])
# Out:
# 0                                     NaN
# 1                                     NaN
# 2        {'place_id': '488da0de4c92ac8e'}
# 3                                     NaN
# 4                                     NaN
#                        ...
# 27263                                 NaN
# 27264    {'place_id': '2a3a6daaec3b0848'}
# 27265                                 NaN
# 27266                                 NaN
# 27267                                 NaN
# Name: geo, Length: 27268, dtype: object

# %%
df["geo"][27236]
# Out:
# {'coordinates': {'coordinates': [-71.68527778, -33.44222222], 'type': 'Point'},
#  'place_id': '001bbfee6edcdb06'}

# %%
df['geo'].tail(40)
# Out:
# 27228                                                  NaN
# 27229                                                  NaN
# 27230                                                  NaN
# 27231                                                  NaN
# 27232                                                  NaN
# 27233                                                  NaN
# 27234                                                  NaN
# 27235                                                  NaN
# 27236    {'coordinates': {'coordinates': [-71.68527778,...
# 27237                                                  NaN
# 27238                                                  NaN
# 27239                                                  NaN
# 27240                                                  NaN
# 27241                                                  NaN
# 27242    {'coordinates': {'coordinates': [-118.55781592...
# 27243                                                  NaN
# ...

# %%
import re
i=0
df['user_geo']="NaN"
for value in df['geo']:
    if isinstance(value, dict):
      my_string = str(value)
      matches = re.findall(r'\[(.*?)\]', my_string)
      #print(matches.types)
      if not matches:
        df['user_geo'][i] = "NaN"
        i += 1

      else:
        df['user_geo'][i] = str(matches)
        i += 1
# Out:
# <ipython-input-17-a195e7ea4226>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['user_geo'][i] = "NaN"
# <ipython-input-17-a195e7ea4226>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['user_geo'][i] = str(matches)

# %%
df['user_geo']
# Out:
# 0                                   NaN
# 1                 ['-98.4933, 29.4239']
# 2               ['-98.50385, 29.40534']
# 3        ['-116.15290175, 43.57641407']
# 4                                   NaN
#                       ...
# 27263                               NaN
# 27264                               NaN
# 27265                               NaN
# 27266                               NaN
# 27267                               NaN
# Name: user_geo, Length: 27268, dtype: object

# %%
df['New_location']="NaN"
for i in range(n):
  if(df['user_geo'][i]!="NaN"):
    df['New_location'][i] = df['user_geo'][i]
  elif(df['user_geo'][i]=="NaN" and df['twitter_places_nafis'][i]!="NaN"):
    df['New_location'][i] = df['twitter_places_nafis'][i]
  else:
    df['New_location'][i] = df['user_location'][i]
# Out:
# <ipython-input-19-d34ea016d44d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['New_location'][i] = df['user_location'][i]
# <ipython-input-19-d34ea016d44d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['New_location'][i] = df['user_geo'][i]
# <ipython-input-19-d34ea016d44d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['New_location'][i] = df['twitter_places_nafis'][i]

# %%
df['New_location'].sample(20)
# Out:
# 5876                                                   NaN
# 5953                                             Ohio, USA
# 10695                                      Market Weighton
# 4015                                                 Earth
# 12969                                      Minneapolis, MN
# 18712                                          Seattle, WA
# 2404                                      Leipzig, Germany
# 1506                                                 india
# 15296                                                  NaN
# 9285                                              Virginia
# 7081                                           Decatur, GA
# 27077                                                  NaN
# 8305                                          New York, NY
# 4152                                                   NaN
# 9040                                   Ramsey, Isle of Man
# 19787                                           Isla Sorna
# ...

# %%
df['New_location'].value_counts()
# Out:
# NaN                               5662
# Washington, DC                     241
# Los Angeles, CA                    220
# Center Valley, PA                  215
# London, England                    215
#                                   ...
# West Yorkshire, United Kingdom       1
# 21 ; she!her ; lesbian               1
# Kennewick, WA                        1
# Abuja  or  Ebonyi                    1
# Patchogue, NY                        1
# Name: New_location, Length: 8649, dtype: int64

# %%
df
# Out:
#         author_id      conversation_id                created_at  \
# 0        22788836  1223395490366025728 2020-01-31 23:59:49+00:00
# 1      3157671046  1223383749263593472 2020-01-31 23:59:11+00:00
# 2       181634813  1223394798876479488 2020-01-31 23:57:04+00:00
# 3      1633428576  1223394344545275904 2020-01-31 23:55:15+00:00
# 4      1225992186  1223358325452087296 2020-01-31 23:55:10+00:00
# ...           ...                  ...                       ...
# 27263  2612253354  1212163653568540672 2020-01-01 00:08:30+00:00
# 27264  2221442917  1212163086624247808 2020-01-01 00:06:15+00:00
# 27265   114743976  1212161757105577984 2020-01-01 00:00:58+00:00
# 27266  3279247754  1212161708803801088 2020-01-01 00:00:46+00:00
# 27267  2491046567  1212161581670391808 2020-01-01 00:00:16+00:00
#
#       edit_history_tweet_ids  \
# 0      [1223395490366025728]
# 1      [1223395330974191617]
# 2      [1223394798876479489]
# 3      [1223394344545275905]
# 4      [1223394321560244224]
# ...

# %%
df['New_location']
# Out:
# 0                               Auckland, New Zealand
# 1                               ['-98.4933, 29.4239']
# 2                             ['-98.50385, 29.40534']
# 3                      ['-116.15290175, 43.57641407']
# 4                            Innsmouth, Massachusetts
#                              ...
# 27263                               Hamilton, Ontario
# 27264    [80.056161, 12.850328, 80.268192, 13.028593]
# 27265                       London Brighton Sussex UK
# 27266                                             NaN
# 27267                                   Patchogue, NY
# Name: New_location, Length: 27268, dtype: object

# %%
df.head(10)
# Out:
#              author_id      conversation_id                created_at  \
# 0             22788836  1223395490366025728 2020-01-31 23:59:49+00:00
# 1           3157671046  1223383749263593472 2020-01-31 23:59:11+00:00
# 2            181634813  1223394798876479488 2020-01-31 23:57:04+00:00
# 3           1633428576  1223394344545275904 2020-01-31 23:55:15+00:00
# 4           1225992186  1223358325452087296 2020-01-31 23:55:10+00:00
# 5            378517016  1223394253562351616 2020-01-31 23:54:54+00:00
# 6           1960044362  1223391099764559872 2020-01-31 23:42:22+00:00
# 7            518046429  1223390232827043840 2020-01-31 23:38:55+00:00
# 8  1215591528531259392  1223389935484301312 2020-01-31 23:37:46+00:00
# 9           3379003163  1150073652374728704 2020-01-31 23:37:29+00:00
#
#   edit_history_tweet_ids                                           entities  \
# 0  [1223395490366025728]  {'annotations': [{'end': 7, 'normalized_text':...
# ...

# %%
df1 = df.drop(['author_id',  'in_reply_to_user_id' ,'lang' , 'conversation_id', 'created_at', 'edit_history_tweet_ids', 'entities', 'id', 'public_metrics', 'user',  'referenced_tweets', 'retweeted_status', 'geo', 'twitter_places', 'attachments', 'withheld'], axis=1)

# %%
df1.rename(columns = {'text':'Tweet', 'twitter_places_nafis':'Twitter_Place',
                              'geocoordinates':'Geo_Code'}, inplace = True)

# %%
df1.head(10)
# Out:
#                                                Tweet  \
# 0  Alonso L is starting a bike ride and you can t...
# 1  @BoycottsBat Few of my mates agree, got to tal...
# 2  My mamba mentality just got me through a 3 mil...
# 3  RT @BillyCorben: TONIGHT #SuperBowl Miami traf...
# 4  @originaltomtom @sibilia_ralph @AMarch4OurLive...
# 5  Be grateful for what you have. This cyclist ro...
# 6  RT @future_crunch: Following improvements in c...
# 7  Wondering where the new @BikeShareTO stations ...
# 8  •bowling\n•boxing\n•football \n•trampoline \n•...
# 9  @x3nome It was so nice to finally meet you on ...
#
#                     user_location  \
# 0           Auckland, New Zealand
# 1        Scotland, United Kingdom
# 2  Somewhere making it happen, TX
# 3              Coral Springs, FL
# 4        Innsmouth, Massachusetts
# 5                           MoDOT
# 6                             NaN
# 7                         Toronto
# 8                       Neverland
# ...

# %% [markdown]
# Now it time to Geoparse and install **Mordecai**

# %%
# !pip install -q https://github.com/ac74475/mordecai/archive/refs/heads/performance-improvement.zip
#pip install mordecai
# !pip install -q spacy==3.4.0
# !pip install -q srsly==2.4.0
# Out:
#      / 1.2 MB 4.3 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 47.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.2/369.2 kB 33.1 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# confection 0.1.1 requires srsly<3.0.0,>=2.4.0, but you have srsly 1.0.7 which is incompatible.
# en-core-web-sm 3.6.0 requires spacy<3.7.0,>=3.6.0, but you have spacy 2.3.9 which is incompatible.
# ...

# %%
# !python -m spacy download en_core_web_lg
# Out:
# 2023-08-30 01:38:26.772350: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-30 01:38:27.893620: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEPRECATION: https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.1/en_core_web_lg-3.4.1-py3-none-any.whl#egg=en_core_web_lg==3.4.1 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# ...

# %%
# !sed -i 's/collections.Mapping/collections.abc.Mapping/g' /usr/local/lib/python3.10/dist-packages/elasticsearch_dsl/search.py
# !sed -i 's/collections.Mapping/collections.abc.Mapping/g' /usr/local/lib/python3.10/dist-packages/elasticsearch_dsl/query.py
# !sed -i 's/collections.Mapping/collections.abc.Mapping/g' /usr/local/lib/python3.10/dist-packages/elasticsearch_dsl/utils.py

# %%
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-5.5.2.tar.gz -q
# !tar -xzf elasticsearch-5.5.2.tar.gz
# !wget https://andrewhalterman.com/files/geonames_index.tar.gz --output-file=wget_log.txt
# !tar -xzf geonames_index.tar.gz
# !mkdir /content/elasticsearch-5.5.2/data
# !mv geonames_index/* /content/elasticsearch-5.5.2/data
# !sudo chown -R daemon:daemon elasticsearch-5.5.2/

# %%
import subprocess
bashCommand = "sudo -H -u daemon elasticsearch-5.5.2/bin/elasticsearch"
subprocess.Popen(bashCommand.split())
# Out:
# <Popen: returncode: None args: ['sudo', '-H', '-u', 'daemon', 'elasticsearch...>

# %%
# Sleep for few seconds to let the instance start.
import time
time.sleep(20)

# %%
# check if it is running
# !ps -ef | grep elasticsearch
# Out:
# root        2738     153  0 01:43 ?        00:00:00 sudo -H -u daemon elasticsearch-5.5.2/bin/elasticsearch
# daemon      2739    2738 13 01:43 ?        00:00:19 /bin/java -Xms2g -Xmx2g -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=75 -XX:+UseCMSInitiatingOccupancyOnly -XX:+AlwaysPreTouch -server -Xss1m -Djava.awt.headless=true -Dfile.encoding=UTF-8 -Djna.nosys=true -Djdk.io.permissionsUseCanonicalPath=true -Dio.netty.noUnsafe=true -Dio.netty.noKeySetOptimization=true -Dio.netty.recycler.maxCapacityPerThread=0 -Dlog4j.shutdownHookEnabled=false -Dlog4j2.disable.jmx=true -Dlog4j.skipJansi=true -XX:+HeapDumpOnOutOfMemoryError -Des.path.home=/content/elasticsearch-5.5.2 -cp /content/elasticsearch-5.5.2/lib/* org.elasticsearch.bootstrap.Elasticsearch
# root        3419     153  0 01:46 ?        00:00:00 /bin/bash -c ps -ef | grep elasticsearch
# root        3421    3419  0 01:46 ?        00:00:00 grep elasticsearch

# %% [markdown]
# # **GeoParse Interface**

# %%
from mordecai import Geoparser
geo = Geoparser()
# Out:
# Models path: /usr/local/lib/python3.10/dist-packages/mordecai/models/

# %%
from tqdm import tqdm
import pandas as pd
geonames = geo.geoparse("I traveled from Colorado to Ottawa.")

print(geonames)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# ...
# 1/1 [==============================] - 0s 90ms/step
# [{'word': 'Colorado', 'spans': [{'start': 16, 'end': 24}], 'country_predicted': 'CRI', 'country_conf': 0.19161285}, {'word': 'Ottawa', 'spans': [{'start': 28, 'end': 34}], 'country_predicted': 'CAN', 'country_conf': 0.94244355, 'geo': {'admin1': 'Ontario', 'lat': '45.41117', 'lon': '-75.69812', 'country_code3': 'CAN', 'geonameid': '6094817', 'place_name': 'Ottawa', 'feature_class': 'P', 'feature_code': 'PPLC'}}]

# %%
df1
# Out:
#                                                    Tweet  \
# 0      Alonso L is starting a bike ride and you can t...
# 1      @BoycottsBat Few of my mates agree, got to tal...
# 2      My mamba mentality just got me through a 3 mil...
# 3      RT @BillyCorben: TONIGHT #SuperBowl Miami traf...
# 4      @originaltomtom @sibilia_ralph @AMarch4OurLive...
# ...                                                  ...
# 27263  RT @SoBiHamilton: Together we have ridden over...
# 27264  😍😍😍😍2⃣0⃣2⃣0⃣ first bike ride https://t.co/rKrK...
# 27265  Should of gone out for a bike ride in the dark...
# 27266  RT @DomLadMaster: Happy Friday everyone!\n\nTi...
# 27267  Brooklyn gets first public bike parking hub - ...
#
#                         user_location  \
# 0               Auckland, New Zealand
# 1            Scotland, United Kingdom
# 2      Somewhere making it happen, TX
# 3                  Coral Springs, FL
# 4            Innsmouth, Massachusetts
# ...                               ...
# ...

# %% [markdown]
# Lets Start the **Naughty** Game

# %%
import multiprocessing as mp
import os
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
from geopy.distance import great_circle as GRC
from mordecai import Geoparser
from dask.distributed import Client, progress
import dask.dataframe as dd
from multiprocessing.pool import ThreadPool as Pool

# %%
geolocator = Nominatim(user_agent='my_geocoder')

# %%
def geoparse_location(location):
    try:
        location_data = geo.geoparse(location)
        if location_data:
            return location_data
        else:
            return None
    except GeocoderTimedOut:
        return geoparse_location(location)


def reverse_geoparse_coordinates(lat_long):
    try:
        location_data = geolocator.reverse(lat_long, timeout=10)
        if location_data:
            return location_data
        else:
            return None
    except GeocoderTimedOut:
        return reverse_geoparse_coordinates(lat_long)




def parsingFunction(df):
    # Iterate over each row in the DataFrame without using index
    for index, row in df.iterrows():
        location = row['New_location']
        # Check if the location is a city name or coordinates
        if pd.isnull(location):
            continue
        if "['" in location:
            # Reverse geoparse coordinates
            split_string = location.split(',')
            listSize = len(split_string)

            if listSize == 2:
                lat = split_string[1].strip("']")
                long = split_string[0].strip("['")

                location_data = reverse_geoparse_coordinates((lat, long))

            if listSize == 4:
                # print("list size = 4: ")
                # print(listSize)
                lon1 = split_string[0][2:]
                lat1 = split_string[1]
                lon2 = split_string[2]
                lat2 = split_string[3][:-2]

                coord1 = lat1 + "," + lon1
                coord2 = lat2 + "," + lon2

                distance = GRC(coord1, coord2).km
                # print(distance)
                if distance <= 200:
                    latitude = (float(lat1) + float(lat2)) / 2
                    longitude = (float(lon1) + float(lon2)) / 2

                    coordinates = (latitude, longitude)
                    # print("four: ")
                    # print(coordinates)
                    location_data = reverse_geoparse_coordinates(coordinates)
                else:
                    location = row['user_location']
                    if pd.isnull(location):
                        pass
            # Extract country, state, latitude, and longitude from the geocoded/reverse geocoded location
            if location_data:
                address = location_data.raw.get('address', {})
                df.at[index, 'Country_conf'] = 99
                df.at[index, 'Country'] = address.get('country', '')
                df.at[index, 'State'] = address.get('state', '')
                df.at[index, 'City'] = address.get('city', '')
                df.at[index, 'Latitude'] = location_data.latitude
                df.at[index, 'Longitude'] = location_data.longitude
        else:
            # Geoparse city name
            geonames = geoparse_location(location)
            if geonames is None:
                geonames = {}
            my_dict = {key: value for key, value in enumerate(geonames)}

            if my_dict is None:
                my_dict = {}

            for key in my_dict.keys():
                value = my_dict[key]
                df.at[index, 'Country_conf'] = value['country_conf']
                df.at[index, 'Country'] = value['country_predicted']
                df.at[index, 'City'] = value['word']
                column_name = 'geo'
                if column_name in value:
                    df.at[index, 'State'] = value['geo']['admin1']
                    df.at[index, 'Latitude'] = value['geo']['lat']
                    df.at[index, 'Longitude'] = value['geo']['lon']
    return df

# %% [markdown]
# **Main Function**

# %%
if __name__ == '__main__':
    # df = pd.read_csv("E:\Tweet\Dav\Processed_data_Sample\Davnet.csv")
    # Create empty columns for country, state, latitude, and longitude
    df1['Country_conf'] = ''
    df1['Country'] = ''
    df1['State'] = ''
    df1['City'] = ''
    df1['Latitude'] = ''
    df1['Longitude'] = ''

    num_chunks = mp.cpu_count()
    df_split = np.array_split(df1, num_chunks)
    pool = mp.Pool()
    pool.map_async(parsingFunction, df_split)

    pool.close()
    pool.join()

    # df_processed = pd.concat(df_split)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %% [markdown]
# normal

# %%
if __name__ == '__main__':
    # df = pd.read_csv("E:\Tweet\Dav\Processed_data_Sample\Tweetpie_main_00.csv")
    #     # Create empty columns for country, state, latitude, and longitude
    df1['Country_conf'] = ''
    df1['Country'] = ''
    df1['State'] = ''
    df1['City'] = ''
    df1['Latitude'] = ''
    df1['Longitude'] = ''

    df_processed = parsingFunction(df1)

    #os.makedirs("E:\Tweet\Dav\Processed_data_Sample", exist_ok=True)
    #df_processed.to_csv("E:\Tweet\Dav\Processed_data_Sample\Davnet8.csv")
# Out:
# 1/1 [==============================] - 0s 32ms/step
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# 1/1 [==============================] - 0s 33ms/step
# WARNING:elasticsearch:GET http://localhost:9200/geonames/_search [status:N/A request:0.004s]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# ...

# %%
df_processed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-f5fca44ad23e> in <cell line: 1>()
# ----> 1 df_processed
#
# NameError: name 'df_processed' is not defined
